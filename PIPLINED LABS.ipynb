# %% [markdown]
# **Lab1**

# %%
print("Welcome To Economic Data Analysis")
# Out:
# Welcome To Economic Data Analysis

# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv('c:/Users/Lenovo/Desktop/My Course/Lab 5/source_indicator_countries_years.csv')
df.head()
# Out:
#          Country Name Country Code  \
# 0  Russian Federation          RUS
# 1  Russian Federation          RUS
# 2  Russian Federation          RUS
# 3  Russian Federation          RUS
# 4  Russian Federation          RUS
#
#                                          Series Name           Series Code  \
# 0     Adjusted net national income (annual % growth)     NY.ADJ.NNTY.KD.ZG
# 1   Adjusted net national income (constant 2015 US$)        NY.ADJ.NNTY.KD
# 2         Adjusted net national income (current US$)        NY.ADJ.NNTY.CD
# 3  Adjusted net national income per capita (annua...  NY.ADJ.NNTY.PC.KD.ZG
# 4  Adjusted net national income per capita (const...     NY.ADJ.NNTY.PC.KD
#
#   1975 [YR1975] 1976 [YR1976] 1977 [YR1977] 1978 [YR1978] 1979 [YR1979]  \
# 0            ..            ..            ..            ..            ..
# 1            ..            ..            ..            ..            ..
# 2            ..            ..            ..            ..            ..
# ...

# %%
df.tail()
# Out:
#                                        Country Name Country Code Series Name  \
# 5                                               NaN          NaN         NaN
# 6                                               NaN          NaN         NaN
# 7                                               NaN          NaN         NaN
# 8  Data from database: World Development Indicators          NaN         NaN
# 9                          Last Updated: 10/07/2025          NaN         NaN
#
#   Series Code 1975 [YR1975] 1976 [YR1976] 1977 [YR1977] 1978 [YR1978]  \
# 5         NaN           NaN           NaN           NaN           NaN
# 6         NaN           NaN           NaN           NaN           NaN
# 7         NaN           NaN           NaN           NaN           NaN
# 8         NaN           NaN           NaN           NaN           NaN
# 9         NaN           NaN           NaN           NaN           NaN
#
#   1979 [YR1979] 1980 [YR1980]  ... 2015 [YR2015] 2016 [YR2016] 2017 [YR2017]  \
# ...

# %%
df.sample(5)
# Out:
#                                        Country Name Country Code  \
# 5                                               NaN          NaN
# 9                          Last Updated: 10/07/2025          NaN
# 2                                Russian Federation          RUS
# 4                                Russian Federation          RUS
# 8  Data from database: World Development Indicators          NaN
#
#                                          Series Name        Series Code  \
# 5                                                NaN                NaN
# 9                                                NaN                NaN
# 2         Adjusted net national income (current US$)     NY.ADJ.NNTY.CD
# 4  Adjusted net national income per capita (const...  NY.ADJ.NNTY.PC.KD
# 8                                                NaN                NaN
#
#   1975 [YR1975] 1976 [YR1976] 1977 [YR1977] 1978 [YR1978] 1979 [YR1979]  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 54 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country Name   7 non-null      object
#  1   Country Code   5 non-null      object
#  2   Series Name    5 non-null      object
#  3   Series Code    5 non-null      object
#  4   1975 [YR1975]  5 non-null      object
#  5   1976 [YR1976]  5 non-null      object
#  6   1977 [YR1977]  5 non-null      object
#  7   1978 [YR1978]  5 non-null      object
#  8   1979 [YR1979]  5 non-null      object
#  9   1980 [YR1980]  5 non-null      object
#  10  1981 [YR1981]  5 non-null      object
#  11  1982 [YR1982]  5 non-null      object
#  12  1983 [YR1983]  5 non-null      object
#  13  1984 [YR1984]  5 non-null      object
#  14  1985 [YR1985]  5 non-null      object
#  15  1986 [YR1986]  5 non-null      object
#  16  1987 [YR1987]  5 non-null      object
# ...

# %% [markdown]
# **Lab 2**

# %%
df.isnull()
# Out:
#    Country Name  Country Code  Series Name  Series Code  1975 [YR1975]  \
# 0         False         False        False        False          False
# 1         False         False        False        False          False
# 2         False         False        False        False          False
# 3         False         False        False        False          False
# 4         False         False        False        False          False
# 5          True          True         True         True           True
# 6          True          True         True         True           True
# 7          True          True         True         True           True
# 8         False          True         True         True           True
# 9         False          True         True         True           True
#
#    1976 [YR1976]  1977 [YR1977]  1978 [YR1978]  1979 [YR1979]  1980 [YR1980]  \
# 0          False          False          False          False          False
# ...

# %%
(df.isnull().sum()/len(df) * 100).round(1)
# Out:
# Country Name     30.0
# Country Code     50.0
# Series Name      50.0
# Series Code      50.0
# 1975 [YR1975]    50.0
# 1976 [YR1976]    50.0
# 1977 [YR1977]    50.0
# 1978 [YR1978]    50.0
# 1979 [YR1979]    50.0
# 1980 [YR1980]    50.0
# 1981 [YR1981]    50.0
# 1982 [YR1982]    50.0
# 1983 [YR1983]    50.0
# 1984 [YR1984]    50.0
# 1985 [YR1985]    50.0
# 1986 [YR1986]    50.0
# 1987 [YR1987]    50.0
# 1988 [YR1988]    50.0
# 1989 [YR1989]    50.0
# 1990 [YR1990]    50.0
# 1991 [YR1991]    50.0
# 1992 [YR1992]    50.0
# 1993 [YR1993]    50.0
# 1994 [YR1994]    50.0
# 1995 [YR1995]    50.0
# 1996 [YR1996]    50.0
# 1997 [YR1997]    50.0
# 1998 [YR1998]    50.0
# 1999 [YR1999]    50.0
# 2000 [YR2000]    50.0
# 2001 [YR2001]    50.0
# 2002 [YR2002]    50.0
# 2003 [YR2003]    50.0
# 2004 [YR2004]    50.0
# 2005 [YR2005]    50.0
# 2006 [YR2006]    50.0
# 2007 [YR2007]    50.0
# 2008 [YR2008]    50.0
# 2009 [YR2009]    50.0
# 2010 [YR2010]    50.0
# 2011 [YR2011]    50.0
# ...

# %%
df.isnull().sum()
# Out:
# Country Name     3
# Country Code     5
# Series Name      5
# Series Code      5
# 1975 [YR1975]    5
# 1976 [YR1976]    5
# 1977 [YR1977]    5
# 1978 [YR1978]    5
# 1979 [YR1979]    5
# 1980 [YR1980]    5
# 1981 [YR1981]    5
# 1982 [YR1982]    5
# 1983 [YR1983]    5
# 1984 [YR1984]    5
# 1985 [YR1985]    5
# 1986 [YR1986]    5
# 1987 [YR1987]    5
# 1988 [YR1988]    5
# 1989 [YR1989]    5
# 1990 [YR1990]    5
# 1991 [YR1991]    5
# 1992 [YR1992]    5
# 1993 [YR1993]    5
# 1994 [YR1994]    5
# 1995 [YR1995]    5
# 1996 [YR1996]    5
# 1997 [YR1997]    5
# 1998 [YR1998]    5
# 1999 [YR1999]    5
# 2000 [YR2000]    5
# 2001 [YR2001]    5
# 2002 [YR2002]    5
# 2003 [YR2003]    5
# 2004 [YR2004]    5
# 2005 [YR2005]    5
# 2006 [YR2006]    5
# 2007 [YR2007]    5
# 2008 [YR2008]    5
# 2009 [YR2009]    5
# 2010 [YR2010]    5
# 2011 [YR2011]    5
# 2012 [YR2012]    5
# 2013 [YR2013]    5
# 2014 [YR2014]    5
# 2015 [YR2015]    5
# 2016 [YR2016]    5
# 2017 [YR2017]    5
# ...

# %%
df.isnull().sum().sum()
# Out:
# 268

# %%
df_clean = df.dropna(thresh=len(df) * 0.5, axis=1)
print(f"Original: {df.shape}, Cleaned: {df_clean.shape}")
# Out:
# Original: (10, 54), Cleaned: (10, 54)

# %%
print(f"Duplicated rows: {df_clean.duplicated().sum()}")
print(f"Duplicated columns: {df_clean.T.duplicated().sum()}")
df_final = df_clean.drop_duplicates().T.drop_duplicates().T
print(f"After removing duplicates: {df_final.shape}")
# Out:
# Duplicated rows: 2
# Duplicated columns: 19
# After removing duplicates: (8, 35)

# %%
print("Duplicated rows:")
print(df_clean[df_clean.duplicated()].index.tolist())
print("\nDuplicated columns:")
print(df_clean.columns[df_clean.T.duplicated()].tolist())
# Out:
# Duplicated rows:
# [6, 7]
#
# Duplicated columns:
# ['1976 [YR1976]', '1977 [YR1977]', '1978 [YR1978]', '1979 [YR1979]', '1980 [YR1980]', '1981 [YR1981]', '1982 [YR1982]', '1983 [YR1983]', '1984 [YR1984]', '1985 [YR1985]', '1986 [YR1986]', '1987 [YR1987]', '1988 [YR1988]', '1989 [YR1989]', '1990 [YR1990]', '1991 [YR1991]', '2022 [YR2022]', '2023 [YR2023]', '2024 [YR2024]']

# %%
df_final.columns = df_final.columns.str.replace(r' \[YR\d+\]', '', regex=True)
df_final.columns
# Out:
# Index(['Country Name', 'Country Code', 'Series Name', 'Series Code', '1975',
#        '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000',
#        '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009',
#        '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
#        '2019', '2020', '2021'],
#       dtype='object')

# %%
df_russia = df_final[df_final['Country Name'].str.contains('Russia', case=False, na=False)]
df_russia.shape
# Out:
# (5, 35)

# %%
df_final = df_final.apply(pd.to_numeric, errors='ignore')

# %%
df_final.isnull().sum().sum()
# Out:
# 103

# %%
df_russia = df_russia.fillna(df_russia.select_dtypes(include=[np.number]).mean())

# %%
df_russia.head()
# Out:
#          Country Name Country Code  \
# 0  Russian Federation          RUS
# 1  Russian Federation          RUS
# 2  Russian Federation          RUS
# 3  Russian Federation          RUS
# 4  Russian Federation          RUS
#
#                                          Series Name           Series Code  \
# 0     Adjusted net national income (annual % growth)     NY.ADJ.NNTY.KD.ZG
# 1   Adjusted net national income (constant 2015 US$)        NY.ADJ.NNTY.KD
# 2         Adjusted net national income (current US$)        NY.ADJ.NNTY.CD
# 3  Adjusted net national income per capita (annua...  NY.ADJ.NNTY.PC.KD.ZG
# 4  Adjusted net national income per capita (const...     NY.ADJ.NNTY.PC.KD
#
#   1975         1992            1993            1994            1995  \
# 0   ..           ..      -21.730187      -14.645257      -10.468234
# 1   ..     5.40E+11  423000000000.0  361000000000.0  323000000000.0
# 2   ..     2.31E+11  216000000000.0  198000000000.0  189000000000.0
# ...

# %%
df_russia.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ### Simple Pipeline for Lab 2 (Beginner Level)
#
# In Lab 2 we **clean and prepare** the raw data so that it is ready for analysis and plotting. The simple pipeline here is:
#
# 1. **Start from the raw DataFrame `df`** that we loaded in Lab 1.
# 2. **Handle missing values** (for example, drop columns with too many missing values).
# 3. **Remove duplicated rows and columns** to avoid counting the same data twice.
# 4. **Clean column names** (remove the `[YR...]` year tags to make names shorter).
# 5. **Convert numeric-looking columns to real numbers** so that we can calculate with them.
# 6. **Focus on Russia only** by keeping only rows where the country name contains "Russia".
# 7. **Fill any remaining numeric gaps in the Russia data** using simple averages.
#
# After this pipeline, we get two main outputs:
# - **`df_final`**: a general cleaned version of the dataset.
# - **`df_russia`**: the cleaned subset for Russia that Lab 3 uses for visualizations.

# %%
def lab2_simple_pipeline(df):
  
    import numpy as np
    import pandas as pd

    # 1. Drop columns with too many missing values (here: more than 50% missing)
    df_clean = df.dropna(thresh=len(df) * 0.5, axis=1)

    # 2. Remove duplicated rows and columns
    df_no_dupes = df_clean.drop_duplicates().T.drop_duplicates().T

    # 3. Remove the year suffix "[YR....]" from column names to make them shorter
    df_no_dupes.columns = df_no_dupes.columns.str.replace(r" \[YR\d+\]", "", regex=True)

    # 4. Convert numeric-looking columns to numeric values where possible
    df_final = df_no_dupes.apply(pd.to_numeric, errors="ignore")

    # 5. Keep only rows for Russia (case-insensitive search in 'Country Name')
    df_russia = df_final[df_final["Country Name"].str.contains("Russia", case=False, na=False)]

    # 6. Fill any remaining numeric missing values in the Russia subset with column means
    df_russia = df_russia.fillna(df_russia.select_dtypes(include=[np.number]).mean())

    print("✅ Cleaning done.")
    print("Original shape:", df.shape)
    print("After cleaning (df_final):", df_final.shape)
    print("Russia subset (df_russia):", df_russia.shape)

    return df_final, df_russia

# Example usage (uses the `df` created in Lab 1):
df_final_simple, df_russia_simple = lab2_simple_pipeline(df)
# Out:
# ✅ Cleaning done.
# Original shape: (10, 54)
# After cleaning (df_final): (8, 35)
# Russia subset (df_russia): (5, 35)

# %% [markdown]
# **Lab 3**

# %%
print(df_russia['Series Name'].unique())
# Out:
# ['Adjusted net national income (annual % growth)'
#  'Adjusted net national income (constant 2015 US$)'
#  'Adjusted net national income (current US$)'
#  'Adjusted net national income per capita (annual % growth)'
#  'Adjusted net national income per capita (constant 2015 US$)']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid", context="notebook")

# Get year columns and prepare data
years = sorted([str(c) for c in df_russia.columns if str(c).isdigit()])
row = df_russia.iloc[0]
series = row[years].apply(pd.to_numeric, errors='coerce').dropna()

# Create plot
x = [int(year) for year in series.index]
y = series.values

plt.figure(figsize=(10, 4))
plt.plot(x, y, marker='o', lw=2)
plt.title(f"{row['Series Name']} — {row['Country Name']} ({x[0]}–{x[-1]})", loc='left')
plt.xlabel("Year")
plt.ylabel("Value")
plt.annotate(f"{y[-1]:,.2f}",
             xy=(x[-1], y[-1]),
             xytext=(8, 8), textcoords="offset points",
             bbox=dict(boxstyle="round,pad=0.2", fc="#f0f0f0", ec="none"),
             fontsize=9)
plt.tight_layout()
plt.show()

# %%
import numpy as np, matplotlib.pyplot as plt, seaborn as sns
from matplotlib.ticker import FuncFormatter
import re

sns.set_theme(style="whitegrid", context="notebook")

def abbreviate(name):
    """Abbreviate indicator names using predefined mapping"""
    mapping = {
        "adjusted net national income per capita (annual % growth)": "ANNIPCA",
        "adjusted net national income per capita (constant 2015 us$)": "ANNIPCC",
        "adjusted net national income (annual % growth)": "ANNIAG",
        "adjusted net national income (constant 2015 us$)": "ANNIC",
        "adjusted net national income (current us$)": "ANNICUR",
    }
    return mapping.get(name.strip().lower(), "Indicator") if isinstance(name, str) else "Indicator"

# Prepare data
years = sorted(int(c) for c in df_russia.columns if str(c).isdigit())
cols = [str(y) for y in years]
df_plot = df_russia.copy()
df_plot[cols] = df_plot[cols].apply(pd.to_numeric, errors="coerce")

# Get name column
name_col = next((c for c in ["Indicator Name", "Series Name", "Indicator"] if c in df_plot.columns), None)

# Select indicators
target_names = [
    "Adjusted net national income (constant 2015 US$)",
    "Adjusted net national income (current US$)",
]
subset = pd.DataFrame([df_plot[df_plot[name_col] == t].dropna(how="all", subset=cols).iloc[0] for t in target_names])
print(f"Number of indicators: {len(subset)}")

# Create plot
fig, ax = plt.subplots(figsize=(10, 4))
for i, (_, row) in enumerate(subset.iterrows()):
    y = row[cols].to_numpy(dtype=float)
    label = abbreviate(row[name_col])
    ax.plot(years, y, marker="o", linewidth=2, label=label, alpha=0.8)
    if not np.isnan(y[-1]):
        ax.text(years[-1] + 0.3, y[-1], label, fontsize=9, va="center", fontweight='bold')

ax.set_title(f"Indicator trends ({years[0]}–{years[-1]})", loc="left")
ax.set_xlabel("Year")
ax.set_ylabel("Value (US$)")
ax.yaxis.set_major_formatter(FuncFormatter(lambda v, _: f"{v:,.0f}"))
ax.legend(loc='best')
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Number of indicators: 2

# %%
import pandas as pd, seaborn as sns, matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter
import re

sns.set_theme(style="whitegrid", context="notebook")

def abbreviate_indicator(name):
    """Abbreviate long indicator names for better display"""
    if not isinstance(name, str):
        return "Indicator"
    name = re.sub(r'\(constant 2015 US\$\)', '(const.)', name, flags=re.IGNORECASE)
    name = re.sub(r'\(current US\$\)', '(curr.)', name, flags=re.IGNORECASE)
    return re.sub(r'Adjusted net national income', 'ANNI', name, flags=re.IGNORECASE)

last_year = str(sorted([int(c) for c in df_russia.columns if str(c).isdigit()])[-1])

# Prepare data
df_temp = df_russia.copy()
df_temp[last_year] = pd.to_numeric(df_temp[last_year], errors='coerce')
df_filtered = df_temp[~df_temp['Series Name'].str.contains('growth|%|per capita', case=False, na=False)]

# Get top 2 indicators
top = df_filtered[['Series Name', last_year]].nlargest(2, last_year).iloc[::-1]
top['Series Name'] = top['Series Name'].apply(abbreviate_indicator)

# Create plot
fig, ax = plt.subplots(figsize=(12, 6))
sns.barplot(data=top, y='Series Name', x=last_year, palette='viridis', ax=ax)

ax.set_title(f"Russia — Comparison: Current vs Constant National Income ({last_year})", loc='left', fontsize=14, fontweight='bold')
ax.set_xlabel("Value (US$)", fontsize=11)
ax.set_ylabel("")
ax.xaxis.set_major_formatter(StrMethodFormatter('{x:,.0f}'))
ax.bar_label(ax.containers[0], fmt='{:,.0f}', padding=3, fontsize=9)

plt.tight_layout()
plt.show()

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sns

sns.set_theme(style="whitegrid", context="notebook")

# Prepare data
last_year = str(sorted([int(c) for c in df_russia.columns if str(c).isdigit()])[-1])
df_temp = df_russia.copy()
df_temp[last_year] = pd.to_numeric(df_temp[last_year], errors='coerce')

summary = pd.DataFrame({'Indicator': df_temp['Series Name'], f'Value ({last_year})': df_temp[last_year]})
summary['Type'] = summary['Indicator'].apply(
    lambda x: 'Percentage/Growth' if any(w in x.lower() for w in ['growth', '%']) else 'Absolute Value (US$)'
)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Plot 1: Dollar indicators
dollar_data = summary[summary['Type'] == 'Absolute Value (US$)'].sort_values(f'Value ({last_year})')
ax1.barh(range(len(dollar_data)), dollar_data[f'Value ({last_year})'], color=sns.color_palette("Blues_r", len(dollar_data)))
ax1.set_yticks(range(len(dollar_data)))
ax1.set_yticklabels(['Total (curr.)' if 'current' in ind.lower() and 'per capita' not in ind.lower() else
                      'Total (const.)' if 'constant' in ind.lower() and 'per capita' not in ind.lower() else
                      'Per Capita (const.)' for ind in dollar_data['Indicator']], fontsize=10)
ax1.set_xlabel("Value (US$)", fontsize=11)
ax1.set_title("Absolute Values", fontsize=12, fontweight='bold')
ax1.set_xscale('log')
ax1.set_xticks([])
ax1.grid(False)
for i, val in enumerate(dollar_data[f'Value ({last_year})']):
    ax1.text(val / 2, i, f'${val/1e12:.2f}T' if val >= 1e12 else f'${val/1e3:.1f}K',
             va='center', ha='center', fontsize=11, color='black', fontweight='bold',
             bbox=dict(boxstyle='round,pad=0.3', facecolor='white', alpha=0.8, edgecolor='none'))

# Plot 2: Percentage indicators
pct_data = summary[summary['Type'] == 'Percentage/Growth'].sort_values(f'Value ({last_year})')
ax2.barh(range(len(pct_data)), pct_data[f'Value ({last_year})'], color=sns.color_palette("Reds_r", len(pct_data)))
ax2.set_yticks(range(len(pct_data)))
ax2.set_yticklabels(['Total Growth' if 'per capita' not in ind.lower() else 'Per Capita Growth'
                      for ind in pct_data['Indicator']], fontsize=10)
ax2.set_xlabel("Growth Rate", fontsize=11)
ax2.set_title("Growth Rates", fontsize=12, fontweight='bold')
ax2.set_xticks([])
ax2.grid(False)
for i, val in enumerate(pct_data[f'Value ({last_year})']):
    ax2.text(val / 2, i, f'{val:.1f}%', va='center', ha='center', fontsize=10, color='white', fontweight='bold')

fig.suptitle(f"Russia — Economic Indicators Summary ({last_year})", fontsize=14, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

# %%
import numpy as np, pandas as pd, seaborn as sns, matplotlib.pyplot as plt

sns.set_theme(style="whitegrid", context="notebook")

years_str = [str(y) for y in sorted([int(c) for c in df_russia.columns if str(c).isdigit()])]

df_temp = df_russia.copy()
df_temp[years_str] = df_temp[years_str].apply(pd.to_numeric, errors='coerce')

# Extract indicator data
current_income = df_temp[df_temp['Series Name'].str.contains('current', case=False, na=False) &
                         ~df_temp['Series Name'].str.contains('per capita', case=False, na=False)][years_str].values.flatten()
constant_income = df_temp[df_temp['Series Name'].str.contains('constant', case=False, na=False) &
                          ~df_temp['Series Name'].str.contains('per capita', case=False, na=False)][years_str].values.flatten()
total_growth = df_temp[df_temp['Series Name'].str.contains('growth', case=False, na=False) &
                       ~df_temp['Series Name'].str.contains('per capita', case=False, na=False)][years_str].values.flatten()
per_capita_growth = df_temp[df_temp['Series Name'].str.contains('per capita.*growth', case=False, na=False, regex=True)][years_str].values.flatten()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

# Plot 1: Current vs Constant Income
mask1 = ~(np.isnan(current_income) | np.isnan(constant_income))
x1, y1 = constant_income[mask1], current_income[mask1]
sns.scatterplot(x=x1, y=y1, ax=ax1, s=100, alpha=0.7, color='steelblue', label='Yearly Data')
sns.regplot(x=x1, y=y1, ax=ax1, scatter=False, color='red', line_kws={'linewidth': 2}, label='Trend Line')
r1 = np.corrcoef(x1, y1)[0, 1]
ax1.set_title(f"Current vs Constant Income\n(r = {r1:.3f})", fontsize=13, fontweight='bold')
ax1.set_xlabel("Constant 2015 US$ (Trillions)", fontsize=11)
ax1.set_ylabel("Current US$ (Trillions)", fontsize=11)
ax1.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x/1e12:.1f}T'))
ax1.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x/1e12:.1f}T'))
ax1.grid(True, alpha=0.3)
ax1.legend(loc='upper left', fontsize=10, frameon=True, shadow=True)

# Plot 2: Total Growth vs Per Capita Growth
mask2 = ~(np.isnan(total_growth) | np.isnan(per_capita_growth))
x2, y2 = total_growth[mask2], per_capita_growth[mask2]
sns.scatterplot(x=x2, y=y2, ax=ax2, s=100, alpha=0.7, color='coral', label='Yearly Data')
sns.regplot(x=x2, y=y2, ax=ax2, scatter=False, color='darkred', line_kws={'linewidth': 2}, label='Trend Line')
r2 = np.corrcoef(x2, y2)[0, 1]
ax2.set_title(f"Total vs Per Capita Growth\n(r = {r2:.3f})", fontsize=13, fontweight='bold')
ax2.set_xlabel("Total Growth (%)", fontsize=11)
ax2.set_ylabel("Per Capita Growth (%)", fontsize=11)
ax2.axhline(y=0, color='gray', linestyle='--', linewidth=1, alpha=0.5, label='Zero Line')
ax2.axvline(x=0, color='gray', linestyle='--', linewidth=1, alpha=0.5)
ax2.grid(True, alpha=0.3)
ax2.legend(loc='upper left', fontsize=10, frameon=True, shadow=True)

fig.suptitle(f"Russia — Indicator Correlations Across All Years", fontsize=15, fontweight='bold', y=1.00)
plt.tight_layout()
plt.show()

print(f"\nCorrelation Analysis:")
print(f"1. Current vs Constant Income: r = {r1:.3f} ({len(x1)} data points)")
print(f"2. Total vs Per Capita Growth: r = {r2:.3f} ({len(x2)} data points)")
# Out:
# Correlation Analysis:
# 1. Current vs Constant Income: r = 0.945 (30 data points)
# 2. Total vs Per Capita Growth: r = 0.999 (29 data points)

# %% [markdown]
# ### Simple Pipeline for Lab 3 (Beginner Level)
#
# In Lab 3 we mainly **visualize** the cleaned Russia data from Lab 2. A simple "pipeline" here means:
#
# 1. **Start with the prepared `df_russia` table** (already cleaned in Lab 2).
# 2. **Pick one economic indicator** (for example, adjusted net national income for Russia).
# 3. **Collect the year columns** and turn them into numbers we can plot.
# 4. **Draw an easy-to-read chart** that shows how this indicator changes over time.
#
# The goal is to see the big picture: *how has this economic indicator for Russia moved across the years?*

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid", context="notebook")

def lab3_simple_pipeline(df_russia):
    """Simple visualization pipeline for Lab 3.

    Steps:
    1. Take the cleaned Russia data (`df_russia`).
    2. Choose one indicator (first row in the table).
    3. Turn the year columns into numeric values.
    4. Plot the indicator over time.
    """
    # 1. Pick the first indicator row for Russia
    row = df_russia.iloc[0]

    # 2. Collect all year columns and convert them to numbers
    years = sorted([c for c in df_russia.columns if str(c).isdigit()])
    series = row[years].apply(pd.to_numeric, errors="coerce").dropna()

    x = [int(y) for y in series.index]
    y = series.values

    # 3. Plot a simple line chart
    plt.figure(figsize=(10, 4))
    plt.plot(x, y, marker="o")
    plt.title(f"{row['Series Name']} — {row['Country Name']}")
    plt.xlabel("Year")
    plt.ylabel("Value")
    plt.tight_layout()
    plt.show()

    return series

# Example usage (uses the `df_russia` created in Lab 2):
lab3_series = lab3_simple_pipeline(df_russia)
